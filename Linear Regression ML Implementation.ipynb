# %% [raw]
# Content
# Each record in the database describes a Boston suburb or town. The data was drawn from the Boston Standard Metropolitan Statistical Area (SMSA) in 1970. The attributes are deﬁned as follows (taken from the UCI Machine Learning Repository
# 1): CRIM: per capita crime rate by town
# 1)ZN: proportion of residential land zoned for lots over 25,000 sq.ft.
# 2)INDUS: proportion of non-retail business acres per town
# 3)CHAS: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
# 4)NOX: nitric oxides concentration (parts per 10 million)
# 5)RM: average number of rooms per dwelling
# 6)AGE: proportion of owner-occupied units built prior to 1940
# 7)DIS: weighted distances to ﬁve Boston employment centers
# 8)RAD: index of accessibility to radial highways
# 9)TAX: full-value property-tax rate per $10,000
# 10)PTRATIO: pupil-teacher ratio by town
# 11). B: 1000(Bk−0.63)2 where Bk is the proportion of blacks by town
# 12)LSTAT: % lower status of the population
# 13)MEDV: Median value of owner-occupied homes in $1000s
# We can see that the input attributes have a mixture of units.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Data Gathering / preparing the dataset

# %%
boston=pd.read_csv("Boston.csv")
boston.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 boston=pd.read_csv("Boston.csv")
#       2 boston.head()
#
# File g:\endtoendprojects\bostenhouseprice\venv\lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
#boston.shape
# Out:
# (506, 17)

# %%
#boston.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV', 'CAT. MEDV', 'Unnamed: 15',
#        'Unnamed: 16'],
#       dtype='object')

# %%
#boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CRIM         506 non-null    float64
#  1   ZN           506 non-null    float64
#  2   INDUS        506 non-null    float64
#  3   CHAS         506 non-null    int64
#  4   NOX          506 non-null    float64
#  5   RM           506 non-null    float64
#  6   AGE          506 non-null    float64
#  7   DIS          506 non-null    float64
#  8   RAD          506 non-null    int64
#  9   TAX          506 non-null    int64
#  10  PTRATIO      506 non-null    float64
#  11  B            506 non-null    float64
#  12  LSTAT        506 non-null    float64
#  13  MEDV         506 non-null    float64
#  14  CAT. MEDV    506 non-null    int64
#  15  Unnamed: 15  0 non-null      float64
#  16  Unnamed: 16  0 non-null      float64
# dtypes: float64(13), int64(4)
# memory usage: 67.3 KB

# %%
## check missing values
boston.isnull().sum()
# Out:
# CRIM             0
# ZN               0
# INDUS            0
# CHAS             0
# NOX              0
# RM               0
# AGE              0
# DIS              0
# RAD              0
# TAX              0
# PTRATIO          0
# B                0
# LSTAT            0
# MEDV             0
# CAT. MEDV        0
# Unnamed: 15    506
# Unnamed: 16    506
# dtype: int64

# %%
## summering the Stats of the data
#boston.corr()
# Out:
#                  CRIM        ZN     INDUS      CHAS       NOX        RM  \
# CRIM         1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247
# ZN          -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991
# INDUS        0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676
# CHAS        -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251
# NOX          0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188
# RM          -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000
# AGE          0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265
# DIS         -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246
# RAD          0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847
# TAX          0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048
# PTRATIO      0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501
# B           -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069
# ...

# %%
# checking: multicolinearity 
plt.figure(figsize=(12,10))
sns.heatmap(boston.corr(),annot=True)
# Out:
# <Axes: >

# %%
import seaborn as sns
#sns.pairplot(boston)

# %%
#There are cases of multicolinearity, we will drop a few columns
boston.drop(columns = [ "NOX","INDUS","TAX","CAT. MEDV","Unnamed: 15","Unnamed: 16"], inplace = True)

# %%
#boston.head(0)
# Out:
# Empty DataFrame
# Columns: [CRIM, ZN, CHAS, RM, AGE, DIS, RAD, PTRATIO, B, LSTAT, MEDV]
# Index: []

# %%
boston.rename(columns={"MEDV":"PRICE"},inplace=True)

# %%
#boston.head(1)
# Out:
#       CRIM    ZN  CHAS     RM   AGE   DIS  RAD  PTRATIO      B  LSTAT  PRICE
# 0  0.00632  18.0     0  6.575  65.2  4.09    1     15.3  396.9   4.98   24.0

# %%
plt.scatter(boston["CRIM"],boston["PRICE"])
plt.xlabel("CRIM")
plt.ylabel("PRICE")
# Out:
# Text(0, 0.5, 'PRICE')

# %%
sns.regplot(x="CRIM",y="PRICE",data=boston)
# Out:
# <Axes: xlabel='CRIM', ylabel='PRICE'>

# %%
plt.scatter(boston["RM"],boston["PRICE"])
plt.xlabel("RM")
plt.ylabel("PRICE")
# Out:
# Text(0, 0.5, 'PRICE')

# %%
sns.regplot(x="RM",y="PRICE",data=boston)
# Out:
# <Axes: xlabel='RM', ylabel='PRICE'>

# %%
boston.shape
# Out:
# (506, 11)

# %%
#boston.head(1) # columns drop zhale ahet
# Out:
#       CRIM    ZN  CHAS     RM   AGE   DIS  RAD  PTRATIO      B  LSTAT  PRICE
# 0  0.00632  18.0     0  6.575  65.2  4.09    1     15.3  396.9   4.98   24.0

# %% [markdown]
# ### Independent and Dependent variables

# %%
x = boston.iloc[:,:-1]
y = boston.iloc[:,-1]
print(x.shape)
print(y.shape)
# Out:
# (506, 10)
# (506,)

# %% [markdown]
# ### splitting

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)
print(x_train.shape)
print(x_test.shape)
# Out:
# (354, 10)
# (152, 10)

# %%
x_train
# Out:
#          CRIM    ZN  CHAS     RM   AGE     DIS  RAD  PTRATIO       B  LSTAT
# 5     0.02985   0.0     0  6.430  58.7  6.0622    3     18.7  394.12   5.21
# 116   0.13158   0.0     0  6.176  72.5  2.7301    6     17.8  393.30  12.04
# 45    0.17142   0.0     0  5.682  33.8  5.1004    3     17.9  396.90  10.21
# 16    1.05393   0.0     0  5.935  29.3  4.4986    4     21.0  386.85   6.58
# 468  15.57570   0.0     0  5.926  71.0  2.9084   24     20.2  368.74  18.13
# ..        ...   ...   ...    ...   ...     ...  ...      ...     ...    ...
# 106   0.17120   0.0     0  5.836  91.9  2.2110    5     20.9  395.67  18.66
# 270   0.29916  20.0     0  5.856  42.1  4.4290    3     18.6  388.65  13.00
# 348   0.01501  80.0     0  6.635  29.7  8.3440    4     17.0  390.94   5.99
# 435  11.16040   0.0     0  6.629  94.6  2.1247   24     20.2  109.85  23.27
# 102   0.22876   0.0     0  6.405  85.4  2.7147    5     20.9   70.80  10.63
#
# [354 rows x 10 columns]

# %% [markdown]
# ### Standardization

# %%
#rules: 1) we apply feature scaling only on i/p variables....eg. x_train, x_test
#       2) we Fit  only on train data and transform on both train and test data...
#   eg. x_train=StandardScaler.fit_transform(x_train)    x_test=StandardScaler.transform(x_test)
from sklearn.preprocessing import StandardScaler           #standardization

scaler =StandardScaler()
x_train =scaler.fit_transform(x_train)
x_test =scaler.transform(x_test)

# %% [raw]
# WHY do you Standardization here?
# internally we use gradient descent.we need to come global minima and come to the global minima wehave to make sure all our independent feature Units should be in same scale

# %%
x_train
# Out:
# array([[-0.41425879, -0.50512499, -0.28154625, ...,  0.18727079,
#          0.39651419, -1.01531611],
#        [-0.40200818, -0.50512499, -0.28154625, ..., -0.21208981,
#          0.3870674 , -0.05366252],
#        [-0.39721053, -0.50512499, -0.28154625, ..., -0.16771641,
#          0.42854113, -0.31132373],
#        ...,
#        [-0.41604586,  3.03838247, -0.28154625, ..., -0.56707702,
#          0.35987906, -0.90549329],
#        [ 0.92611293, -0.50512499, -0.28154625, ...,  0.8528718 ,
#         -2.87841346,  1.52750437],
#        [-0.39030549, -0.50512499, -0.28154625, ...,  1.16348561,
#         -3.32828832, -0.25218837]])

# %%
x_test
# Out:
# array([[-0.406801  , -0.50512499, -0.28154625, ..., -0.74457062,
#          0.41241246, -0.47605794],
#        [-0.41105674,  1.26662874,  3.55181427, ..., -0.30083661,
#          0.42854113, -1.25185755],
#        [-0.4051199 , -0.50512499, -0.28154625, ...,  0.8084984 ,
#          0.35031705,  0.79535229],
#        ...,
#        [-0.35439903, -0.50512499, -0.28154625, ..., -0.38958342,
#          0.25688594, -1.09697922],
#        [ 0.25423453, -0.50512499, -0.28154625, ...,  0.8528718 ,
#         -2.98970133,  0.53487511],
#        [ 0.77732457, -0.50512499, -0.28154625, ...,  0.8528718 ,
#          0.33199949,  0.56585078]])

# %% [markdown]
# ### Training model

# %%
from sklearn.linear_model import LinearRegression
Regression=LinearRegression()
Regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(Regression.intercept_)
# Out:
# 23.01581920903955

# %%
print(Regression.coef_)
# Out:
# [-0.98425958  0.62948477  0.81669339  3.13250015 -0.79305299 -2.15710782
#   0.39453955 -1.73177991  1.11114763 -4.11750509]

# %%
reg_pred=Regression.predict(x_test)
#reg_pred
# Out:
# array([27.46553236, 35.62096883, 17.90465981, 25.37975029, 19.61350556,
#        22.12199573, 17.0248219 , 14.72348397, 21.41224854, 21.02879172,
#        23.06399223, 18.23759622, -7.70053351, 21.49067569, 18.60135682,
#        26.29146912, 18.22131936,  4.99797358, 39.6619103 , 18.18541581,
#        27.19210072, 29.12112765, 10.63649662, 24.86772452, 18.59299616,
#        14.3809148 , 22.93856446, 15.09425675, 20.73462052, 20.00105221,
#        20.44579767, 25.26781361, 25.58928894, 19.89477703, 15.12134639,
#        20.60140262, 30.94044918, 20.35624907, 23.13260767, 24.85152049,
#        14.18466463, 29.73198171, 41.0892192 , 17.52471578, 26.5702917 ,
#        17.35626755, 13.45476625, 26.16229628, 19.40172228, 30.93444723,
#        21.0738606 , 32.98785014, 15.54425847, 26.70006405, 39.35080042,
#        23.26628853, 19.86875553, 32.03154765, 24.35177274, 12.16271687,
#        22.90505506, 30.71443549, 31.46601158, 17.06235073, 23.43061179,
# ...

# %%
y_test
# Out:
# 173    23.6
# 274    32.4
# 491    13.6
# 72     22.8
# 452    16.1
#        ...
# 441    17.1
# 23     14.5
# 225    50.0
# 433    14.3
# 447    12.6
# Name: PRICE, Length: 152, dtype: float64

# %%
## plot a scatter for the prediction
plt.scatter(y_test,reg_pred)           #here wecan say our modelperforming not best but it is performing well

# %%
residuals=y_test-reg_pred

# %%
# checking: data Normally distributed or not
sns.displot(residuals,kind="kde") #

# %% [raw]
# it looks like normally distributed but here some outliers

# %%
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error,mean_absolute_error

# %%
mean_absolute_percentage_error(y_test,reg_pred)
# Out:
# 0.17951246614278668

# %%
100-0.17951246614278668 # 99.82 % accuracy
# Out:
# 99.82048753385722

# %% [markdown]
# ### R square and Adjusted R square

# %%
from sklearn.metrics import r2_score
r2_score(y_test,reg_pred)
# Out:
# 0.6643580797708983

# %% [markdown]
# ### New Data Prediction
# important note:step1:prediction kadte veli array ha 2D asava
# step2: model Standerdization kel asel tr prediction sathi standerdization kelelech input gheyawe.jr i/p  standerdize nasel tr tyala standerdize karawe ani mng prediction kadave.

# %%
boston
# Out:
#         CRIM    ZN  CHAS     RM   AGE     DIS  RAD  PTRATIO       B  LSTAT  \
# 0    0.00632  18.0     0  6.575  65.2  4.0900    1     15.3  396.90   4.98
# 1    0.02731   0.0     0  6.421  78.9  4.9671    2     17.8  396.90   9.14
# 2    0.02729   0.0     0  7.185  61.1  4.9671    2     17.8  392.83   4.03
# 3    0.03237   0.0     0  6.998  45.8  6.0622    3     18.7  394.63   2.94
# 4    0.06905   0.0     0  7.147  54.2  6.0622    3     18.7  396.90   5.33
# ..       ...   ...   ...    ...   ...     ...  ...      ...     ...    ...
# 501  0.06263   0.0     0  6.593  69.1  2.4786    1     21.0  391.99   9.67
# 502  0.04527   0.0     0  6.120  76.7  2.2875    1     21.0  396.90   9.08
# 503  0.06076   0.0     0  6.976  91.0  2.1675    1     21.0  396.90   5.64
# 504  0.10959   0.0     0  6.794  89.3  2.3889    1     21.0  393.45   6.48
# 505  0.04741   0.0     0  6.030  80.8  2.5050    1     21.0  396.90   7.88
#
#      PRICE
# 0     24.0
# 1     21.6
# 2     34.7
# 3     33.4
# ...

# %%
# thod cross check krtoy acutal ani predicted madhe kay differnce ahe te
new_predicted_values=pd.DataFrame({"actual_values":y_test,"predicted_values":reg_pred,"difference":y_test-reg_pred})
new_predicted_values.head(20).abs()
# Out:
#      actual_values  predicted_values  difference
# 173           23.6         27.465532    3.865532
# 274           32.4         35.620969    3.220969
# 491           13.6         17.904660    4.304660
# 72            22.8         25.379750    2.579750
# 452           16.1         19.613506    3.513506
# 76            20.0         22.121996    2.121996
# 316           17.8         17.024822    0.775178
# 140           14.0         14.723484    0.723484
# 471           19.6         21.412249    1.812249
# 500           16.8         21.028792    4.228792
# 218           21.5         23.063992    1.563992
# 9             18.9         18.237596    0.662404
# 414            7.0          7.700534   14.700534
# 78            21.2         21.490676    0.290676
# 323           18.5         18.601357    0.101357
# 473           29.8         26.291469    3.508531
# 124           18.8         18.221319    0.578681
# 388           10.2          4.997974    5.202026
# ...

# %%
# Q.1)
z=np.array([0.04527,0.0,0.0,6.120,76.7,2.2875,1.0,21.0,396.90,9.08]) #row:502-----> ans 20.6
#print(z.shape) # print(z.ndim)
z.reshape(1,-1)                  # 2D array madhe convert karne
#print(z.reshape(1,-1))
# Out:
# array([[4.5270e-02, 0.0000e+00, 0.0000e+00, 6.1200e+00, 7.6700e+01,
#         2.2875e+00, 1.0000e+00, 2.1000e+01, 3.9690e+02, 9.0800e+00]])

# %%
## new test data la staderdize krun ghetoy
scaler.transform(z.reshape(1,-1))
# Out:
# array([[-0.41240187, -0.50512499, -0.28154625, -0.28637414,  0.28597006,
#         -0.69635201, -0.97798895,  1.20785901,  0.42854113, -0.470426  ]])

# %%
## new test data sathi prediction kadhtoy
Regression.predict(scaler.transform(z.reshape(1,-1)))
# Out:
# array([23.18762683])

# %%
#Q.2)
zp=np.array([0.04741,0.0,0.0,6.030,80.8,2.5050,1.0,21.0,396.90,7.88]) #row:505-----> ans 11.9
zp.reshape(1,-1)
# Out:
# array([[4.741e-02, 0.000e+00, 0.000e+00, 6.030e+00, 8.080e+01, 2.505e+00,
#         1.000e+00, 2.100e+01, 3.969e+02, 7.880e+00]])

# %%
scaler.transform(zp.reshape(1,-1))
# Out:
# array([[-0.41214416, -0.50512499, -0.28154625, -0.41168839,  0.4343796 ,
#         -0.59390394, -0.97798895,  1.20785901,  0.42854113, -0.63938418]])

# %%
Regression.predict(scaler.transform(zp.reshape(1,-1)))
# Out:
# array([23.15182424])

# %% [markdown]
# ## Pickling The model file For Deployment

# %%
import pickle

# %%
file="proj.pkl"

# %%
# pickle file created(serialize process):
pickle.dump(Regression,open(file,"wb"))        #wb=write byte mode

# %%
# pickle file loaded(## Unserialize process):
pickle_model=pickle.load(open(file,"rb"))       # rb = read byte mode
pickle_model
# Out:
# LinearRegression()

# %%
pickle_model.predict(scaler.transform(zp.reshape(1,-1)))
# Out:
# array([23.15182424])

# %%
file1="scaling.pkl"

# %%
pickle.dump(scaler,open(file1,"wb"))

# %%
pickle.load(open(file1,"rb"))
# Out:
# StandardScaler()
